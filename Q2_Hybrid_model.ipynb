# %% [markdown]
# <a href="https://colab.research.google.com/github/Roua91/Reaserch_Project/blob/main/Q2_Hybrid_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1- Importing necessary libraries

# %%
# !pip install tensorflow
# !pip install tensorflow-gpu
# !pip install tensorflow-quantum
# !pip install pennylane
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ERROR: Could not find a version that satisfies the requirement tensorflow-quantum (from versions: none)
# ERROR: No matching distribution found for tensorflow-quantum
# Collecting pennylane
#   Downloading PennyLane-0.35.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.3)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.9-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.3)
# Collecting pennylane-lightning>=0.35 (from pennylane)
#   Downloading PennyLane_Lightning-0.35.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 33.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.11.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Installing collected packages: semantic-version, rustworkx, autoray, pennylane-lightning, pennylane
# Successfully installed autoray-0.6.9 pennylane-0.35.1 pennylane-lightning-0.35.1 rustworkx-0.14.2 semantic-version-2.10.0

# %% [markdown]
# # 2- Importing and preprocessing the dataset

# %%
import os

os.environ['KAGGLE_USERNAME'] = 'rouaalemam'
os.environ['KAGGLE_KEY'] = 'd16ffbf0d8bee8e95a525fdbfa328074'

# %%
# !kaggle datasets download -d aryashah2k/breast-ultrasound-images-dataset
# Out:
# Downloading breast-ultrasound-images-dataset.zip to /content
#  98% 192M/195M [00:07<00:00, 30.8MB/s]
# 100% 195M/195M [00:07<00:00, 26.3MB/s]

# %%
from zipfile import ZipFile
file_name = "/content/breast-ultrasound-images-dataset.zip"
with ZipFile(file_name, 'r') as zip:
    zip.extractall()  # This line is indented
print('Done')
# Out:
# Done

# %%
import os

# Path to the dataset directory
dataset_dir = '/content/Dataset_BUSI_with_GT'

import shutil


# Path to the 'normal' directory
normal_dir_path = '/content/Dataset_BUSI_with_GT/normal'

# Check if the directory exists
if os.path.exists(normal_dir_path) and os.path.isdir(normal_dir_path):
    # Remove the 'normal' directory and all its contents
    shutil.rmtree(normal_dir_path)
    print(f"'{normal_dir_path}' has been removed.")
else:
    print(f"The directory '{normal_dir_path}' does not exist or is not a directory.")

all_files = os.listdir(dataset_dir)
print(all_files)
# Out:
# '/content/Dataset_BUSI_with_GT/normal' has been removed.
# ['malignant', 'benign']

# %%
from PIL import Image
import os
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, SubsetRandomSampler
from sklearn.model_selection import train_test_split
import torch
import numpy as np

# Overlay and preparation code
dataset_dir = '/content/Dataset_BUSI_with_GT'  # Original dataset directory
overlay_dir = '/content/OverlayOutput'  # Directory to save overlayed images
labels = ['benign', 'malignant']

# Ensure the overlay output directory exists
os.makedirs(overlay_dir, exist_ok=True)
# Create subdirectories for each label in the overlay directory
for label in labels:
    os.makedirs(os.path.join(overlay_dir, label), exist_ok=True)


def overlay_and_save(image_path, mask_path, output_dir):
    try:
        # Construct the full path where the overlayed image will be saved
        output_path = os.path.join(output_dir, os.path.basename(image_path))

        # Check if the overlay image already exists
        if os.path.isfile(output_path):
            print(f"Overlay image already exists: {output_path}, skipping.")
            return  # Skip saving this image

        # Proceed if the overlay does not exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image = Image.open(image_path).convert("RGB")  # Ensure image is in RGB
            mask = Image.open(mask_path).convert("L")      # Ensure mask is in grayscale

            mask = mask.resize(image.size)  # Resize mask to match image size

            # Create an RGBA version of the mask to use as overlay
            rgba_mask = Image.new("RGBA", mask.size, (255, 0, 0, 0))  # Red mask with zero opacity
            rgba_mask.putalpha(mask)  # Set alpha channel to mask values

            overlayed = Image.alpha_composite(image.convert("RGBA"), rgba_mask)

            # Save the overlayed image
            overlayed.convert("RGB").save(output_path)  # Convert back to RGB to save
            print(f"Saved overlayed image to: {output_path}")
    except Exception as e:
        print(f"An error occurred for: {image_path} or {mask_path}. Error: {str(e)}")

# Perform overlay and save for each image in the dataset
for label in labels:
    image_dir = os.path.join(dataset_dir, label)
    output_label_dir = os.path.join(overlay_dir, label)
    for image_filename in os.listdir(image_dir):
        if image_filename.endswith('.png'):
            image_path = os.path.join(image_dir, image_filename)
            mask_path = image_path.replace('.png', '_mask.png')
            overlay_and_save(image_path, mask_path, output_label_dir)

print("Overlayed images have been saved to the overlay directory.")

# Now proceed with loading and transforming the overlayed dataset
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomHorizontalFlip(p=0.9),
    transforms.RandomRotation(15, expand=False, center=None),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0), ratio=(0.75, 1.33)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load the overlayed dataset
overlayed_dataset = datasets.ImageFolder(root=overlay_dir, transform=transform)

# Splitting dataset into train and test sets
train_idx, test_idx = train_test_split(range(len(overlayed_dataset)), test_size=0.2, random_state=42)

# Creating data loaders
train_loader = DataLoader(overlayed_dataset, batch_size=32, sampler=SubsetRandomSampler(train_idx))
test_loader = DataLoader(overlayed_dataset, batch_size=32, sampler=SubsetRandomSampler(test_idx))

dataloaders = {'train': train_loader, 'test': test_loader}
dataset_sizes = {'train': len(train_idx), 'test': len(test_idx)}
class_names = overlayed_dataset.classes

print(f"Dataset split complete: {len(train_loader)} training batches, {len(test_loader)} testing batches.")
# Out:
# Saved overlayed image to: /content/OverlayOutput/benign/benign (307).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (290).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (394).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (312).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (83).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (93).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (279).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (397).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (297).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (92).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (199).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (359).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (383).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (306).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (334).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (223).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (293).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (173).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (429).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (72).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (209).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (137).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (412).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (267).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (19).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (138).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (170).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (302).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (404).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (248).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (125).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (221).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (116).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (200).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (87).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (374).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (304).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (343).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (177).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (82).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (430).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (214).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (65).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (278).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (123).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (43).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (363).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (186).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (277).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (205).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (54).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (85).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (162).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (106).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (132).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (184).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (60).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (207).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (385).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (22).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (409).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (338).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (128).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (189).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (437).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (110).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (118).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (305).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (49).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (101).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (237).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (121).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (403).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (31).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (180).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (393).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (8).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (84).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (155).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (433).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (331).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (38).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (421).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (33).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (294).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (172).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (346).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (348).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (32).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (361).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (42).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (67).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (350).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (220).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (187).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (265).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (262).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (148).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (76).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (382).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (345).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (355).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (364).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (44).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (339).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (284).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (11).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (247).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (252).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (58).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (322).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (310).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (270).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (257).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (250).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (235).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (233).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (64).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (407).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (249).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (157).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (104).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (91).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (268).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (105).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (245).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (198).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (156).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (231).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (153).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (219).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (102).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (179).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (395).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (388).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (30).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (136).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (154).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (142).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (134).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (24).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (51).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (358).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (366).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (25).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (432).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (298).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (26).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (287).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (296).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (202).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (100).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (251).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (365).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (411).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (405).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (15).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (71).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (211).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (69).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (280).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (217).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (333).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (398).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (27).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (78).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (115).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (435).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (75).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (46).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (201).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (34).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (204).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (141).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (130).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (300).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (174).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (291).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (328).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (192).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (427).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (194).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (161).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (165).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (4).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (97).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (387).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (375).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (428).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (79).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (347).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (229).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (210).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (140).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (163).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (368).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (120).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (336).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (107).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (271).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (215).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (325).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (36).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (303).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (144).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (276).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (299).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (340).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (381).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (112).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (81).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (16).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (28).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (183).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (362).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (9).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (390).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (228).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (314).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (414).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (146).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (349).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (197).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (171).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (56).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (208).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (168).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (62).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (13).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (182).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (371).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (254).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (286).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (389).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (341).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (406).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (281).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (23).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (1).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (240).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (352).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (225).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (160).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (431).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (318).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (108).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (236).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (377).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (159).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (17).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (35).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (408).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (288).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (86).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (103).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (227).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (367).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (135).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (317).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (47).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (175).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (283).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (90).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (145).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (139).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (282).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (321).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (158).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (181).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (434).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (402).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (133).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (41).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (196).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (419).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (117).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (129).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (425).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (269).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (315).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (191).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (20).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (351).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (66).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (309).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (311).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (185).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (272).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (423).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (238).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (264).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (316).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (169).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (301).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (3).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (259).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (369).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (241).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (335).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (285).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (263).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (7).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (167).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (260).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (266).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (424).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (360).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (258).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (242).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (89).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (417).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (396).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (88).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (126).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (124).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (399).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (2).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (63).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (50).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (308).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (216).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (436).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (327).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (206).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (354).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (253).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (190).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (232).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (10).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (94).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (418).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (96).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (150).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (212).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (73).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (131).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (386).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (178).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (292).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (392).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (376).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (18).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (274).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (48).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (53).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (218).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (52).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (98).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (29).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (176).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (111).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (99).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (373).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (119).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (152).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (426).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (113).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (95).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (122).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (295).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (353).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (203).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (243).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (320).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (378).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (222).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (55).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (193).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (372).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (147).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (226).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (319).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (401).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (261).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (342).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (109).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (379).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (337).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (59).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (151).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (413).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (230).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (70).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (195).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (149).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (416).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (422).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (244).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (40).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (61).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (323).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (12).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (289).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (6).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (114).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (127).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (410).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (45).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (224).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (313).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (357).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (39).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (213).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (37).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (256).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (420).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (164).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (255).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (324).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (391).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (326).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (344).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (57).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (275).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (80).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (380).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (332).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (329).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (14).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (77).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (74).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (21).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (370).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (188).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (246).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (415).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (68).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (273).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (384).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (239).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (5).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (234).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (166).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (330).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (400).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (356).png
# Saved overlayed image to: /content/OverlayOutput/benign/benign (143).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (2).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (4).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (47).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (53).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (149).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (114).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (205).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (166).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (81).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (51).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (87).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (185).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (148).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (162).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (204).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (126).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (158).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (44).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (170).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (146).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (57).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (19).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (20).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (173).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (161).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (189).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (122).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (123).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (34).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (26).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (154).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (210).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (179).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (147).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (64).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (178).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (117).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (63).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (15).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (151).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (138).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (120).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (186).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (6).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (56).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (167).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (159).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (46).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (40).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (135).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (14).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (190).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (96).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (140).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (203).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (199).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (194).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (128).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (108).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (103).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (195).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (198).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (66).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (74).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (206).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (139).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (90).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (78).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (182).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (55).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (54).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (58).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (183).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (133).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (70).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (208).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (202).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (32).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (41).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (100).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (106).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (143).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (18).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (43).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (59).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (101).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (23).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (160).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (77).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (52).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (89).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (76).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (73).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (11).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (3).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (207).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (153).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (121).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (69).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (5).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (33).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (168).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (49).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (37).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (80).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (137).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (175).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (16).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (112).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (116).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (75).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (21).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (113).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (200).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (188).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (131).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (201).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (99).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (93).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (197).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (31).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (36).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (125).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (29).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (30).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (25).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (115).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (50).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (129).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (136).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (174).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (193).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (39).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (61).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (22).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (8).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (42).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (181).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (48).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (191).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (163).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (111).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (107).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (152).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (127).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (176).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (110).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (88).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (60).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (85).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (104).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (150).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (45).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (132).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (83).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (145).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (209).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (141).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (92).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (95).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (68).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (102).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (10).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (187).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (7).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (184).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (105).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (94).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (82).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (1).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (180).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (155).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (12).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (165).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (169).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (79).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (144).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (98).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (84).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (97).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (35).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (109).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (177).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (130).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (62).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (72).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (134).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (13).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (38).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (142).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (9).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (172).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (67).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (28).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (27).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (156).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (124).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (192).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (24).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (157).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (196).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (17).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (91).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (86).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (118).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (65).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (164).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (171).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (119).png
# Saved overlayed image to: /content/OverlayOutput/malignant/malignant (71).png
# Overlayed images have been saved to the overlay directory.
# Dataset split complete: 17 training batches, 5 testing batches.

# %% [markdown]
# # 3- Quatum Circuit

# %%
import time
n_qubits = 8               # Number of qubits
step = 0.00041             # Learning rate
batch_size = 5              # Number of samples for each training step
num_epochs = 30           # Number of training epochs
q_depth = 1                # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1    # Learning rate reduction applied every 10 epochs.
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %%
import pennylane as qml

# Define your device
dev = qml.device("default.qubit", wires=n_qubits)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the H_layer and RY_layer functions here
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)


def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)

def entangling_layer(nqubits):
    """Layer of CNOT gates to entangle qubits."""
    for i in range(0, nqubits - 1, 2):  # Apply CNOT to pairs (0, 1), (2, 3), ...
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):  # Apply CNOT to pairs (1, 2), (3, 4), ...
        qml.CNOT(wires=[i, (i + 1) % nqubits])

@qml.qnode(dev, interface="torch")
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """

    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+>, unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)

    # Embed features in the quantum node
    RY_layer(q_input_features)

    # Sequence of trainable variational layers
    for k in range(q_depth):
        RY_layer(q_weights[k])
        entangling_layer(n_qubits)  # Apply entangling layer after the RY rotations

    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %%
import torch.nn as nn
class DressedQuantumNet(nn.Module):
    """
    Torch module implementing the *dressed* quantum net.
    """

    def __init__(self):
        """
        Definition of the *dressed* layout.
        """

        super().__init__()
        self.pre_net = nn.Linear(2048, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, 2)

    def forward(self, input_features):
        """
        Defining how tensors are supposed to move through the *dressed* quantum
        net.
        """

        # obtain the input features for the quantum circuit
        # by reducing the feature dimension from 512 to 4
        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = torch.hstack(quantum_net(elem, self.q_params)).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %% [markdown]
# # 4- Hybrid Classical Quantum Model

# %%
import torchvision
model_hybrid = torchvision.models.resnet50(pretrained=True)

for param in model_hybrid.parameters():
    param.requires_grad = False


# Notice that model_hybrid.fc is the last layer of ResNet18
model_hybrid.fc = DressedQuantumNet()

# Use CUDA or CPU according to the "device" object.
model_hybrid = model_hybrid.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 63.6MB/s]

# %% [markdown]
# # 5- Training and Result

# %%
criterion = nn.CrossEntropyLoss()

# %%
import torch.optim as optim
optimizer_hybrid = optim.Adam(model_hybrid.fc.parameters(), lr=step)

# %%
from torch.optim import lr_scheduler
exp_lr_scheduler = lr_scheduler.StepLR(
    optimizer_hybrid, step_size=10, gamma=gamma_lr_scheduler
)

# %%
import torch
import time
import copy

def train_model(model, criterion, optimizer, scheduler, num_epochs, dataloaders, dataset_sizes, device):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_loss = float('inf')  # Initialize with a large number

    print("Training started:")

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and test phase for evaluation
        for phase in ['train', 'test']:  # Use 'test' instead of 'validation'
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                'Train' if phase == 'train' else 'Test',
                epoch_loss, epoch_acc))

            # Deep copy the model if we get the best accuracy on the test set
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                best_loss = epoch_loss

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best test loss: {:.4f} Acc: {:.4f}'.format(best_loss, best_acc))

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_hybrid = train_model(
    model_hybrid,
    criterion,
    optimizer_hybrid,
    exp_lr_scheduler,
    num_epochs=num_epochs,
    dataloaders=dataloaders,
    dataset_sizes=dataset_sizes,
    device=device
)
# Out:
# Training started:
# Epoch 1/30
# ----------
# Train Loss: 0.5704 Acc: 0.7195
# Test Loss: 0.4244 Acc: 0.7846
# Epoch 2/30
# ----------
# Train Loss: 0.4540 Acc: 0.8433
# Test Loss: 0.3749 Acc: 0.9000
# Epoch 3/30
# ----------
# Train Loss: 0.4032 Acc: 0.8801
# Test Loss: 0.3531 Acc: 0.9385
# Epoch 4/30
# ----------
# Train Loss: 0.3571 Acc: 0.8994
# Test Loss: 0.2999 Acc: 0.9231
# Epoch 5/30
# ----------
# Train Loss: 0.3319 Acc: 0.9149
# Test Loss: 0.2766 Acc: 0.9385
# Epoch 6/30
# ----------
# Train Loss: 0.2954 Acc: 0.9342
# Test Loss: 0.2599 Acc: 0.9385
# Epoch 7/30
# ----------
# Train Loss: 0.2758 Acc: 0.9400
# Test Loss: 0.2520 Acc: 0.9462
# Epoch 8/30
# ----------
# Train Loss: 0.2866 Acc: 0.9110
# Test Loss: 0.2510 Acc: 0.9692
# Epoch 9/30
# ----------
# Train Loss: 0.2532 Acc: 0.9323
# Test Loss: 0.2145 Acc: 0.9769
# Epoch 10/30
# ----------
# Train Loss: 0.2309 Acc: 0.9536
# Test Loss: 0.2066 Acc: 0.9462
# Epoch 11/30
# ----------
# Train Loss: 0.2382 Acc: 0.9362
# Test Loss: 0.2092 Acc: 0.9692
# Epoch 12/30
# ----------
# Train Loss: 0.2414 Acc: 0.9400
# Test Loss: 0.1999 Acc: 0.9692
# Epoch 13/30
# ----------
# Train Loss: 0.2404 Acc: 0.9400
# Test Loss: 0.1772 Acc: 0.9769
# Epoch 14/30
# ----------
# Train Loss: 0.2256 Acc: 0.9458
# Test Loss: 0.1753 Acc: 0.9692
# Epoch 15/30
# ----------
# Train Loss: 0.2239 Acc: 0.9439
# Test Loss: 0.1845 Acc: 0.9692
# Epoch 16/30
# ----------
# Train Loss: 0.2248 Acc: 0.9497
# Test Loss: 0.2110 Acc: 0.9538
# Epoch 17/30
# ----------
# Train Loss: 0.2398 Acc: 0.9207
# Test Loss: 0.2080 Acc: 0.9462
# Epoch 18/30
# ----------
# Train Loss: 0.2399 Acc: 0.9284
# Test Loss: 0.1943 Acc: 0.9538
# Epoch 19/30
# ----------
# Train Loss: 0.2132 Acc: 0.9516
# Test Loss: 0.2107 Acc: 0.9538
# Epoch 20/30
# ----------
# Train Loss: 0.2315 Acc: 0.9400
# Test Loss: 0.1940 Acc: 0.9538
# Epoch 21/30
# ----------
# Train Loss: 0.2178 Acc: 0.9497
# Test Loss: 0.1948 Acc: 0.9462
# Epoch 22/30
# ----------
# Train Loss: 0.1997 Acc: 0.9652
# Test Loss: 0.1729 Acc: 0.9769
# Epoch 23/30
# ----------
# Train Loss: 0.2152 Acc: 0.9497
# Test Loss: 0.1727 Acc: 0.9692
# Epoch 24/30
# ----------
# Train Loss: 0.2263 Acc: 0.9342
# Test Loss: 0.1890 Acc: 0.9692
# Epoch 25/30
# ----------
# Train Loss: 0.2218 Acc: 0.9497
# Test Loss: 0.1799 Acc: 0.9692
# Epoch 26/30
# ----------
# Train Loss: 0.2264 Acc: 0.9420
# Test Loss: 0.1820 Acc: 0.9769
# Epoch 27/30
# ----------
# Train Loss: 0.2195 Acc: 0.9458
# Test Loss: 0.1724 Acc: 0.9769
# Epoch 28/30
# ----------
# Train Loss: 0.2390 Acc: 0.9400
# Test Loss: 0.1824 Acc: 0.9769
# Epoch 29/30
# ----------
# Train Loss: 0.2189 Acc: 0.9420
# Test Loss: 0.2174 Acc: 0.9615
# Epoch 30/30
# ----------
# Train Loss: 0.2357 Acc: 0.9420
# Test Loss: 0.1758 Acc: 0.9615
# Training complete in 114m 23s
# Best test loss: 0.2145 Acc: 0.9769

# %%
import numpy as np
import matplotlib.pyplot as plt

# Mean and standard deviation used for ImageNet dataset normalization
# These values may need to be adjusted based on your dataset's normalization
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

def imshow(inp, mean=IMAGENET_MEAN, std=IMAGENET_STD):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))  # Convert tensor to (HxWxC) from (CxHxW)
    mean = np.array(mean)
    std = np.array(std)
    inp = std * inp + mean  # Unnormalize
    inp = np.clip(inp, 0, 1)  # Clip values to [0, 1] range
    plt.imshow(inp)
    plt.pause(0.001)  # pause a bit so that plots are updated



def visualize_model(model, num_images=6, fig_name="Predictions", num_cols=2):
    images_so_far = 0
    fig = plt.figure(fig_name, figsize=(10, num_images * 2))

    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # Disable gradient computation
        for inputs, labels in dataloaders['test']:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                if images_so_far < num_images:
                    images_so_far += 1
                    ax = plt.subplot(num_images // num_cols + num_images % num_cols, num_cols, images_so_far)
                    ax.axis('off')
                    ax.set_title(f'Predicted: {class_names[preds[j]]}\nTrue: {class_names[labels[j]]}', fontsize=9)

                    # imshow function needs to be defined or use plt.imshow after converting tensor to numpy
                    imshow(inputs.cpu().data[j])
                else:
                    plt.tight_layout()
                    return
        plt.tight_layout()

# %%
visualize_model(model_hybrid, num_images=batch_size)
plt.show()

# %% [markdown]
# # 6- Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import torch

def evaluate_model(model, dataloaders, device):
    model.eval()  # Set the model to evaluation mode
    true_labels_list, predictions_list = [], []

    with torch.no_grad():
        for inputs, labels in dataloaders['test']:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            true_labels_list.extend(labels.cpu().numpy())
            predictions_list.extend(preds.cpu().numpy())

    # Calculate metrics
    accuracy = accuracy_score(true_labels_list, predictions_list)
    precision = precision_score(true_labels_list, predictions_list, average='binary')
    recall = recall_score(true_labels_list, predictions_list, average='binary')
    f1 = f1_score(true_labels_list, predictions_list, average='binary')
    # For AUC-ROC, you need model outputs as probabilities. This example assumes binary classification.
    # If your model outputs logits, convert these to probabilities using a softmax layer first.
    # auc_roc = roc_auc_score(true_labels_list, prediction_probabilities)

    # Print metrics
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    # print(f'AUC-ROC: {auc_roc:.4f}')

    # Confusion Matrix
    cm = confusion_matrix(true_labels_list, predictions_list)
    print("Confusion Matrix:")
    print(cm)

# %%
evaluate_model(model_hybrid, dataloaders, device)
# Out:
# Accuracy: 0.9769
# Precision: 0.9737
# Recall: 0.9487
# F1 Score: 0.9610
# Confusion Matrix:
# [[90  1]
#  [ 2 37]]
